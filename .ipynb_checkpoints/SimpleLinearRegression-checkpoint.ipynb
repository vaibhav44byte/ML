# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('weight_height.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     150
# 1      47     152
# 2      49     155
# 3      50     157
# 4      53     160

# %%
##scatter plot
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
## correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.998379
# Height  0.998379  1.000000

# %%
## Seaborn for visualization
import seaborn as sns
sns.pairplot(df)

# %%
## Independent and Dependent features
X = df[['Weight']] ## independent feature should be data frame or 2d array
y = df['Height'] ## this variable can be in series or 1d
# np.array(X).shape
y
# Out:
# 0     150
# 1     152
# 2     155
# 3     157
# 4     160
# 5     162
# 6     165
# 7     167
# 8     170
# 9     172
# 10    175
# 11    177
# 12    180
# 13    182
# 14    185
# 15    187
# 16    190
# 17    192
# 18    195
# 19    197
# 20    200
# 21    202
# 22    205
# 23    207
# Name: Height, dtype: int64

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state=42)

# %%
X_train.shape
# Out:
# (18, 1)

# %%
## Standardization 
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
# Out:
# array([[ 0.08260917],
#        [-1.40435589],
#        [ 1.30404475],
#        [-0.97950873],
#        [-1.2981441 ],
#        [-0.02360262],
#        [ 0.34813864],
#        [-1.2450382 ],
#        [-1.08572052],
#        [ 1.46336243],
#        [ 0.66677401],
#        [ 1.14472707],
#        [ 1.62268012],
#        [-0.71397925],
#        [-0.28913209],
#        [ 0.24192685],
#        [ 0.98540938],
#        [-0.82019104]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.55466157],
#        [ 0.56056222],
#        [-1.51056767],
#        [ 0.8260917 ],
#        [-0.1829203 ],
#        [-0.44844978]])

# %%
## Apply Simple Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression(n_jobs=-1)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficient or slope: ",reg.coef_)
print("Intercept: ",reg.intercept_)
# Out:
# Coefficient or slope [0.95393614]
# Coefficient or slope 109.38313429198152

# %%
## Plot the Training data best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,reg.predict(X_train))

# %%
## prediction for test data 
y_pred=reg.predict(X_test)
# Out:
# B:\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
## performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse = np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 4614.511239534175
# 66.49179975290319
# 67.93019387234351

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# -20.540768234340025
